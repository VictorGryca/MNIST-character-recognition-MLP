# %% [markdown]
# # Testando lógica treinando uma rede XOR

# %%
# importando as bibliotecas essenciais
import numpy as np

# %%
# datasets XOR e pesos iniciais
np.random.seed(42)

X = np.array([[1,1],[1,0],[0,1],[0,0]])  # (4, 2)
y = np.array([[0],[1],[1],[0]])          # (4, 1)

W1 = np.random.uniform(-0.1, 0.1, (4, 2))  # (4 neurônios, 2 entradas) | quantidade no feeling de neuronios, acho que dava pra fazer com 2
b1 = np.zeros((4,))
W2 = np.random.uniform(-0.1, 0.1, (1, 4))  # (1 saída, 4 neurônios)
b2 = np.zeros((1,))

Lr = 0.2

# %%
# @ — multiplicação matricial (W @ x)
# * — multiplicação elemento a elemento
# np.outer() — produto externo (só no backprop)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x)) # 1 é porcentagem mais alta e 0 é mais baixa | funcao ativacao binaria

# %%
def derivada_relu(z):
    return (z > 0).astype(float) | # soh a derivada da relu mesmo

# %%
for epoca in range(1000):
    for i in range(len(X)):
        # forward pass
        x = X[i]
        z1 = W1 @ x + b1
        a1 = np.maximum(0, z1)
        z2 = W2 @ a1 + b2
        a2 = sigmoid(z2)

    # backprop 
        delta2 = 2*(a2 - y[i]) * a2 * (1 - a2)
        dw2 = np.outer(delta2, a1)
        W2 = W2 - Lr * dw2
        b2 = b2 - Lr * delta2

        delta1 = (W2.T @ delta2) * derivada_relu(z1)
        dw1 = np.outer(delta1, x)
        W1 = W1 - Lr * dw1
        b1 = b1 - Lr * delta1

    loss = np.mean((a2 - y[i])**2)
    if epoca % 100 == 0:
        print(f"epoca {epoca}, loss: {loss:.4f}")
# Out:
# epoca 0, loss: 0.2630
# epoca 100, loss: 0.1719
# epoca 200, loss: 0.1089
# epoca 300, loss: 0.0143
# epoca 400, loss: 0.0065
# epoca 500, loss: 0.0041
# epoca 600, loss: 0.0029
# epoca 700, loss: 0.0023
# epoca 800, loss: 0.0018
# epoca 900, loss: 0.0015

# %%
test = np.array([[1,1],[1,0],[0,1],[0,0]])

for i in range(len(X)):
        # forward pass
        x = X[i]
        z1 = W1 @ x + b1
        a1 = np.maximum(0, z1)
        z2 = W2 @ a1 + b2
        a2 = sigmoid(z2)

        predicao = (a2 > 0.5).astype(int)
        print(predicao)
# Out:
# [0]
# [1]
# [1]
# [0]
